# %%
pip install torch torchvision torchreid deep_sort_realtime
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: torchreid in /opt/conda/lib/python3.10/site-packages (0.2.5)
# Requirement already satisfied: deep_sort_realtime in /opt/conda/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from deep_sort_realtime) (1.14.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from deep_sort_realtime) (4.10.0.84)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install deep-sort-realtime
# Out:
# Requirement already satisfied: deep-sort-realtime in /opt/conda/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from deep-sort-realtime) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from deep-sort-realtime) (1.14.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from deep-sort-realtime) (4.10.0.84)

# %%
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.88-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.6-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.88-py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.7/871.7 kB 24.1 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.6-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.2.88 ultralytics-thop-2.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# Path to the log file
log_file = '/kaggle/working/progress.log'

# List of already processed videos
processed_videos = [
    'videoplayback.mp4',
    'Preference Assessment with Toys_ Multiple Stimulus without Replacement (MSWO).mp4',
    'Exploring the Therapeutic Playroom.mp4',
    'Discrete Trial Training.mp4',
    'Group Therapy for Autism Spectrum Disorder.mp4',
    'Matching.mp4'
]

# Write these filenames to the log file
with open(log_file, 'w') as f:
    for video in processed_videos:
        f.write(video + '\n')

print(f"Preloaded {len(processed_videos)} processed videos into the log file.")
# Out:
# Preloaded 6 processed videos into the log file.

# %%
import cv2
import torch
import torchvision.transforms as transforms
import torchvision.models as models
import os
from deep_sort_realtime.deepsort_tracker import DeepSort
from ultralytics import YOLO

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def load_feature_extractor():
    """Load the ResNet model for feature extraction and move it to GPU."""
    model = models.resnet50(pretrained=True)
    model.fc = torch.nn.Identity()  # Remove the final classification layer
    model = model.to(device)
    model.eval()
    return model

def preprocess_image(image):
    """Preprocess image for feature extraction."""
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    return transform(image).unsqueeze(0).to(device)

def extract_features(image, model):
    """Extract features from the image using the feature extractor model."""
    image = preprocess_image(image)
    with torch.no_grad():
        features = model(image)
    return features.cpu().numpy()

def initialize_tracker():
    """Initialize the DeepSORT tracker with default parameters."""
    return DeepSort(
        max_age=20,
        n_init=5,
        nms_max_overlap=0.5,
        max_cosine_distance=0.1,
        nn_budget=100
    )

def load_model(model_path):
    """Load the YOLO model for object detection."""
    model = YOLO(model_path)
    model.to(device)
    return model

def open_video(video_path):
    """Open the input video and return the capture object."""
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    return cap, frame_width, frame_height, fps

def create_video_writer(output_path, frame_width, frame_height, fps):
    """Create a VideoWriter object to save the output video."""
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    return cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

def perform_detection(frame, model):
    """Perform detection on the frame using YOLO model."""
    results = model(frame)
    detections = []

    for result in results:
        if result.boxes is not None:
            for box in result.boxes:
                xyxy = box.xyxy[0]
                conf = box.conf[0]
                cls = int(box.cls[0])
                x1, y1, x2, y2 = map(int, xyxy)
                detections.append(([x1, y1, x2-x1, y2-y1], conf, cls))

    return detections

def update_tracking(detections, tracker, frame, feature_extractor):
    """Update the tracker with the detections."""
    features = []
    for detection in detections:
        bbox, conf, cls = detection
        x1, y1, w, h = bbox
        obj_image = frame[y1:y1+h, x1:x1+w]
        feature = extract_features(obj_image, feature_extractor)
        features.append(feature)

    tracks = tracker.update_tracks(detections, frame=frame)
    return tracks

def draw_tracks(frame, tracks, model):
    """Draw the bounding boxes and labels with IDs."""
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        cls = track.det_class
        label = f'ID {track_id}: {model.names[cls]}'

        color = (0, 255, 0)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    return frame

def process_video(input_video_path, output_video_path, model, tracker, feature_extractor, log_file):
    """Main pipeline to process the video."""
    cap, frame_width, frame_height, fps = open_video(input_video_path)
    out = create_video_writer(output_video_path, frame_width, frame_height, fps)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        detections = perform_detection(frame, model)
        tracks = update_tracking(detections, tracker, frame, feature_extractor)
        frame = draw_tracks(frame, tracks, model)

        out.write(frame)

    cap.release()
    out.release()
    print(f'Video saved to {output_video_path}')

    # Log the processed video filename
    with open(log_file, 'a') as f:
        f.write(os.path.basename(input_video_path) + '\n')

def process_directory(input_dir, output_dir, model, tracker, feature_extractor, log_file):
    """Process all videos in the input directory and save to the output directory."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Read log file to get processed videos
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            processed_videos = set(line.strip() for line in f)
    else:
        processed_videos = set()

    for filename in os.listdir(input_dir):
        if filename.endswith('.mp4'):
            if filename in processed_videos:
                print(f'Skipping {filename} (already processed)')
                continue

            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, f'track_{filename}')
            print(f'Processing {input_path}...')
            process_video(input_path, output_path, model, tracker, feature_extractor, log_file)

if __name__ == "__main__":
    # Load the model and initialize the tracker
    model_path = '/kaggle/input/yolo-model/model c.pt'
    input_dir = '/kaggle/input/test-videos'
    output_dir = '/kaggle/working/output'
    log_file = '/kaggle/working/progress.log'

    model = load_model(model_path)
    feature_extractor = load_feature_extractor()
    tracker = initialize_tracker()

    # Process all videos in the input directory
    process_directory(input_dir, output_dir, model, tracker, feature_extractor, log_file)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Skipping Matching.mp4 (already processed)
# Skipping Group Therapy for Autism Spectrum Disorder.mp4 (already processed)
# Skipping Exploring the Therapeutic Playroom.mp4 (already processed)
# Skipping Discrete Trial Training.mp4 (already processed)
# Skipping videoplayback.mp4 (already processed)
# Skipping Preference Assessment with Toys_ Multiple Stimulus without Replacement (MSWO).mp4 (already processed)
# Processing /kaggle/input/test-videos/Speech Therapy Training Session- Moderate to Severe Autism.mp4...
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 384x640 1 Therapist, 1 Child, 72.9ms
# Speed: 3.5ms preprocess, 72.9ms inference, 135.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 18.8ms
# Speed: 1.3ms preprocess, 18.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 18.6ms
# Speed: 1.3ms preprocess, 18.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 18.8ms
# Speed: 1.3ms preprocess, 18.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 18.4ms
# Speed: 1.3ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.2ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.9ms
# Speed: 1.1ms preprocess, 21.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.2ms preprocess, 21.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 23.0ms
# Speed: 1.2ms preprocess, 23.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.0ms
# Speed: 1.2ms preprocess, 22.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.3ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 2.9ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.0ms
# Speed: 1.1ms preprocess, 20.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.7ms
# Speed: 1.2ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.2ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.0ms
# Speed: 1.1ms preprocess, 20.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 2 Childs, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.2ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.4ms
# Speed: 1.0ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.7ms
# Speed: 1.2ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 22.5ms
# Speed: 1.2ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.8ms
# Speed: 1.3ms preprocess, 22.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.6ms
# Speed: 1.2ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 68.1ms
# Speed: 1.4ms preprocess, 68.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 60.8ms
# Speed: 1.2ms preprocess, 60.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 60.3ms
# Speed: 2.1ms preprocess, 60.3ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 29.2ms
# Speed: 1.5ms preprocess, 29.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 52.0ms
# Speed: 1.1ms preprocess, 52.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.5ms
# Speed: 1.4ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 24.6ms
# Speed: 1.3ms preprocess, 24.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# Speed: 1.2ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.2ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 63.1ms
# Speed: 1.2ms preprocess, 63.1ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 25.8ms
# Speed: 1.3ms preprocess, 25.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 25.7ms
# Speed: 1.3ms preprocess, 25.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 44.5ms
# Speed: 10.9ms preprocess, 44.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 36.1ms
# Speed: 1.1ms preprocess, 36.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.2ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Therapists, 1 Child, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.9ms
# Speed: 1.2ms preprocess, 21.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 21.6ms
# ...
# Speed: 1.4ms preprocess, 32.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.4ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 30.3ms
# Speed: 11.3ms preprocess, 30.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.4ms
# Speed: 1.4ms preprocess, 31.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.4ms
# Speed: 1.3ms preprocess, 31.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.1ms
# Speed: 1.3ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.5ms
# Speed: 1.4ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.5ms
# Speed: 1.3ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.2ms
# Speed: 1.4ms preprocess, 31.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.5ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.5ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.5ms preprocess, 31.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.4ms preprocess, 32.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.7ms
# Speed: 1.3ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.2ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 30.9ms
# Speed: 1.2ms preprocess, 30.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 31.4ms
# Speed: 1.2ms preprocess, 31.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.2ms
# Speed: 1.4ms preprocess, 31.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.1ms
# Speed: 1.3ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.1ms
# Speed: 1.2ms preprocess, 31.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.9ms
# Speed: 1.3ms preprocess, 31.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.7ms
# Speed: 1.3ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.4ms
# Speed: 1.3ms preprocess, 31.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.4ms preprocess, 32.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.0ms
# Speed: 1.5ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.9ms
# Speed: 1.4ms preprocess, 31.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 32.5ms
# Speed: 1.4ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 3 Childs, 32.1ms
# Speed: 1.4ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 34.4ms
# Speed: 1.4ms preprocess, 34.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.4ms
# Speed: 1.3ms preprocess, 31.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 2 Childs, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.7ms
# Speed: 1.4ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.4ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.5ms
# Speed: 1.3ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.9ms
# Speed: 1.3ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Therapist, 1 Child, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
